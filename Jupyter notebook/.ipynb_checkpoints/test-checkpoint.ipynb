# %% [markdown]
# Trabajo Final Probabilidad Aplicada
#
# María Belén Hipólito
#
# - Base de datos:
#
# Se utiliza una base de datos realizada en el año 2019 por alumnos del Instituto Santa María de los Ángeles recopilando información sobre las costumbres nutricionales de las familias.
#
# - Bibliografía:
#
# https://www.youtube.com/playlist?list=PLU8oAlHdN5BlvPxziopYZRd55pdqFwkeS
#
# https://www.youtube.com/watch?v=6Vr9ZUntCyE&ab_channel=LeonardoKuffo
#
# https://www.youtube.com/watch?v=8rfH7al7PgU&ab_channel=LearnUrself123
#
# https://www.youtube.com/watch?v=7VHvxOHNf_M&ab_channel=MundoPython

# %%
#Import pandas in JN:
import pandas

# %%
#importo la tabla de excel
dataset = pandas.read_excel("Encuesta Alimentaria ISMA 2019.xlsx")

# %%
#importo la librería poniendo un nombre
import pandas as pd

# %%
#importo la tabla de excel usando el nombre y lo guardo en la variable dataset
dataset = pd.read_excel("Encuesta Alimentaria ISMA 2019.xlsx")

# %%
#muestro la tabla
#dataset
#también la puedo imprimir y se ve como una consola
#print(dataset)
#Check the header:
#muestro los primeros 10 registros
#dataset.head(10)
#muestro los primeros 5
dataset.head()
# Out:
#            Marca temporal  Edad:  Peso:  Altura:  \
# 0 2019-06-02 21:44:39.858     40   79.0     1.64
# 1 2019-06-02 22:05:15.002     49   90.0     1.74
# 2 2019-06-02 22:12:05.362     13   38.0     1.52
# 3 2019-06-02 22:17:27.454     17   68.0     1.82
# 4 2019-06-13 15:43:00.350     30   51.0     1.50
#
#   1.\t¿Cuáles de las 4 comidas diarias realizas en el día?  \
# 0                           Desayuno, Merienda, Cena
# 1                 Desayuno, Almuerzo, Merienda, Cena
# 2                 Desayuno, Almuerzo, Merienda, Cena
# 3                 Desayuno, Almuerzo, Merienda, Cena
# 4                 Desayuno, Almuerzo, Merienda, Cena
#
#   2.\t¿Qué colaciones consumís diariamente?  \
# 0             Alfajor, Sándwich, Galletitas
# 1                         Fruta, Galletitas
# 2                       Alfajor, Galletitas
# 3                                     Fruta
# 4                                     Fruta
#
#   3.\t¿Qué lácteos  consumís diariamente?  \
# 0                           Leche, Quesos
# 1                                  Quesos
# 2                                   Leche
# 3                                   Leche
# 4                   Yogurt, Leche, Quesos
#
#   4.\t¿Qué carnes  consumís diariamente?  \
# 0                     Vaca, Cerdo, Pollo
# 1                            Vaca, Pollo
# 2                            Vaca, Pollo
# 3                            Vaca, Pollo
# 4            Vaca, Cerdo, Pollo, Pescado
#
#   5.\t¿Consumís frutas y verduras diariamente?  \
# 0                                           Si
# 1                                           Si
# 2                                           Si
# 3                                           Si
# 4                                           Si
#
#   6.\t¿Consumís legumbres diariamente? 7.\t¿Consumís cereales diariamente?  \
# 0                                   No                                  Si
# 1                                   No                                  No
# 2                                   No                                  No
# 3                                   No                                  Si
# 4                                   Si                                  Si
#
#   8.\tComplete el siguiente cuadro. [Galletitas]  \
# 0                                 Todos los días
# 1                                 Todos los días
# 2                                 Todos los días
# 3                         Menos de 1 vez o nunca
# 4                         Menos de 1 vez o nunca
#
#   8.\tComplete el siguiente cuadro. [Hamburguesas comerciales]  \
# 0                             Menos de 1 vez o nunca
# 1                             Menos de 1 vez o nunca
# 2                             Menos de 1 vez o nunca
# 3                             Menos de 1 vez o nunca
# 4                             Menos de 1 vez o nunca
#
#   8.\tComplete el siguiente cuadro. [Sopas instantáneas]  \
# 0                             Menos de 1 vez o nunca
# 1                             Menos de 1 vez o nunca
# 2                             Menos de 1 vez o nunca
# 3                             Menos de 1 vez o nunca
# 4                             Menos de 1 vez o nunca
#
#   8.\tComplete el siguiente cuadro. [Comida de rotisería]  \
# 0                             Menos de 1 vez o nunca
# 1                             Menos de 1 vez o nunca
# 2                             Menos de 1 vez o nunca
# 3                             Menos de 1 vez o nunca
# 4                             Menos de 1 vez o nunca
#
#   8.\tComplete el siguiente cuadro. [Gaseosas]  \
# 0                       Menos de 1 vez o nunca
# 1                       Menos de 1 vez o nunca
# 2                       Menos de 1 vez o nunca
# 3                       Menos de 1 vez o nunca
# 4                       Menos de 1 vez o nunca
#
#   8.\tComplete el siguiente cuadro. [Salsas y aderezos comerciales]  \
# 0                                     Todos los días
# 1                               3-4 veces por semana
# 2                               3-4 veces por semana
# 3                               3-4 veces por semana
# 4                               1-2 veces por semana
#
#   8.\tComplete el siguiente cuadro. [Embutidos y fiambres]  \
# 0                               1-2 veces por semana
# 1                               3-4 veces por semana
# 2                               1-2 veces por semana
# 3                               1-2 veces por semana
# 4                               1-2 veces por semana
#
#   9.\t¿Con qué frecuencia realizas actividad física?  \
# 0                                   1 vez por semana
# 1                        No realizo actividad física
# 2                           3 veces o más por semana
# 3                           3 veces o más por semana
# 4                           3 veces o más por semana
#
#   10.\t¿Consideras que tener buenos hábitos alimenticios?
# 0                                                 No
# 1                                                 No
# 2                                                 Sí
# 3                                                 Sí
# 4                                                 Sí

# %%
#Check the tail:
#muestro los ultimos 10 registros
#dataset.tail(10)
#muestro los ultimos 5
dataset.tail()
# Out:
#              Marca temporal  Edad:  Peso:  Altura:  \
# 110 2019-08-08 16:46:41.635     70   68.0     1.60
# 111 2019-08-08 19:11:19.320     56   75.0     1.63
# 112 2019-08-08 21:48:01.030     12   36.0     1.44
# 113 2019-08-08 21:50:43.514     15   68.0     1.67
# 114 2019-08-08 22:16:57.202     17   64.0     1.58
#
#     1.\t¿Cuáles de las 4 comidas diarias realizas en el día?  \
# 110                 Desayuno, Almuerzo, Merienda, Cena
# 111                 Desayuno, Almuerzo, Merienda, Cena
# 112                 Desayuno, Almuerzo, Merienda, Cena
# 113                 Desayuno, Almuerzo, Merienda, Cena
# 114                 Desayuno, Almuerzo, Merienda, Cena
#
#     2.\t¿Qué colaciones consumís diariamente?  \
# 110                                     Fruta
# 111                         Fruta, Galletitas
# 112                            Alfajor, Fruta
# 113                     No consumo colaciones
# 114                                  Sándwich
#
#     3.\t¿Qué lácteos  consumís diariamente?  \
# 110                           Leche, Quesos
# 111                   Yogurt, Leche, Quesos
# 112                                   Leche
# 113                           Leche, Quesos
# 114                           Leche, Quesos
#
#     4.\t¿Qué carnes  consumís diariamente?  \
# 110                                  Pollo
# 111                     Vaca, Cerdo, Pollo
# 112                            Vaca, Pollo
# 113                                   Vaca
# 114                      No consumo carnes
#
#     5.\t¿Consumís frutas y verduras diariamente?  \
# 110                                           Si
# 111                                           Si
# 112                                           Si
# 113                                           No
# 114                                           Si
#
#     6.\t¿Consumís legumbres diariamente? 7.\t¿Consumís cereales diariamente?  \
# 110                                   No                                  Si
# 111                                   No                                  Si
# 112                                   No                                  No
# 113                                   No                                  Si
# 114                                   No                                  No
#
#     8.\tComplete el siguiente cuadro. [Galletitas]  \
# 110                                 Todos los días
# 111                           3-4 veces por semana
# 112                           1-2 veces por semana
# 113                           3-4 veces por semana
# 114                           3-4 veces por semana
#
#     8.\tComplete el siguiente cuadro. [Hamburguesas comerciales]  \
# 110                             Menos de 1 vez o nunca
# 111                             Menos de 1 vez o nunca
# 112                             Menos de 1 vez o nunca
# 113                             Menos de 1 vez o nunca
# 114                             Menos de 1 vez o nunca
#
#     8.\tComplete el siguiente cuadro. [Sopas instantáneas]  \
# 110                             Menos de 1 vez o nunca
# 111                               3-4 veces por semana
# 112                             Menos de 1 vez o nunca
# 113                             Menos de 1 vez o nunca
# 114                             Menos de 1 vez o nunca
#
#     8.\tComplete el siguiente cuadro. [Comida de rotisería]  \
# 110                             Menos de 1 vez o nunca
# 111                               1-2 veces por semana
# 112                             Menos de 1 vez o nunca
# 113                             Menos de 1 vez o nunca
# 114                             Menos de 1 vez o nunca
#
#     8.\tComplete el siguiente cuadro. [Gaseosas]  \
# 110                       Menos de 1 vez o nunca
# 111                         1-2 veces por semana
# 112                         1-2 veces por semana
# 113                       Menos de 1 vez o nunca
# 114                         3-4 veces por semana
#
#     8.\tComplete el siguiente cuadro. [Salsas y aderezos comerciales]  \
# 110                             Menos de 1 vez o nunca
# 111                               3-4 veces por semana
# 112                               1-2 veces por semana
# 113                             Menos de 1 vez o nunca
# 114                               1-2 veces por semana
#
#     8.\tComplete el siguiente cuadro. [Embutidos y fiambres]  \
# 110                             Menos de 1 vez o nunca
# 111                             Menos de 1 vez o nunca
# 112                             Menos de 1 vez o nunca
# 113                             Menos de 1 vez o nunca
# 114                             Menos de 1 vez o nunca
#
#     9.\t¿Con qué frecuencia realizas actividad física?  \
# 110                                   1 vez por semana
# 111                           3 veces o más por semana
# 112                           3 veces o más por semana
# 113                           3 veces o más por semana
# 114                                   1 vez por semana
#
#     10.\t¿Consideras que tener buenos hábitos alimenticios?
# 110                                                 Sí
# 111                                                 Sí
# 112                                                 Sí
# 113                                                 Sí
# 114                                                 No

# %%
#importo la librería para graficar
import matplotlib.pyplot as plt

# %%
#selecciono los campos que me interesan
campos = dataset[["Peso:","5.\t¿Consumís frutas y verduras diariamente?"]]
print(campos)
# Out:
#      Peso: 5.\t¿Consumís frutas y verduras diariamente?
# 0     79.0                                           Si
# 1     90.0                                           Si
# 2     38.0                                           Si
# 3     68.0                                           Si
# 4     51.0                                           Si
# ..     ...                                          ...
# 110   68.0                                           Si
# 111   75.0                                           Si
# 112   36.0                                           Si
# 113   68.0                                           No
# 114   64.0                                           Si
#
# [115 rows x 2 columns]

# %%
ax = campos.plot.bar(x="Peso:", y="5.\t¿Consumís frutas y verduras diariamente?", rot=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19724/2126762290.py in <module>
# ----> 1 ax = campos.plot.bar(x="Peso:", y="5.\t¿Consumís frutas y verduras diariamente?", rot=0)
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1128         other axis represents a measured value.
#    1129         """
# -> 1130         return self(kind="bar", x=x, y=y, **kwargs)
#    1131
#    1132     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     284     def generate(self):
#     285         self._args_adjust()
# --> 286         self._compute_plot_data()
#     287         self._setup_subplots()
#     288         self._make_plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     451         # no non-numeric frames or series allowed
#     452         if is_empty:
# --> 453             raise TypeError("no numeric data to plot")
#     454
#     455         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
#selecciono los campos que me interesan
x = dataset[["Peso:"]]
y = dataset[["5.\t¿Consumís frutas y verduras diariamente?"]]
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19724/3073395961.py in <module>
#       2 x = dataset[["Peso:"]]
#       3 y = dataset[["5.\t¿Consumís frutas y verduras diariamente?"]]
# ----> 4 plt.plot(x,y)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496             self.axes.xaxis.update_units(x)
#     497         if self.axes.yaxis is not None:
# --> 498             self.axes.yaxis.update_units(y)
#     499
#     500         if x.shape[0] != y.shape[0]:
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1446         neednew = self.converter != converter
#    1447         self.converter = converter
# -> 1448         default = self.converter.default_units(data, self)
#    1449         if default is not None and self.units is None:
#    1450             self.set_units(default)
#
# ~\anaconda3\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     107         # the conversion call stack is default_units -> axis_info -> convert
#     108         if axis.units is None:
# --> 109             axis.set_units(UnitData(data))
#     110         else:
#     111             axis.units.update(data)
#
# ~\anaconda3\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     183         self._counter = itertools.count()
#     184         if data is not None:
# --> 185             self.update(data)
#     186
#     187     @staticmethod
#
# ~\anaconda3\lib\site-packages\matplotlib\category.py in update(self, data)
#     216         # check if convertible to number:
#     217         convertible = True
# --> 218         for val in OrderedDict.fromkeys(data):
#     219             # OrderedDict just iterates over unique values in data.
#     220             _api.check_isinstance((str, bytes), value=val)
#
# TypeError: unhashable type: 'numpy.ndarray'
